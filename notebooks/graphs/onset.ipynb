# %%
from scripts.onset_graphs import composite_onset_graph, smp_time_series

# %%
smp_time_series(seed=60)

# %%
composite_onset_graph(2022, 270, 30)
# Out:
# Processing grid points...
# Number of samples in composite: 23
